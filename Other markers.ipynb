# %%
"""
Female suffix (from WikiDictionary):
-ess, -ress, -a, -ette, -ine, -rix
"""

# %%
"""
-ess & -ress

1. Used to form female equivalents. 

‎actor + ‎-ess → ‎actress
‎chanter + ‎-ess → ‎chantress
‎duke + ‎-ess → ‎duchess (“female ruler of a duchy”)
‎god + ‎-ess → ‎goddess
‎lion + ‎-ess → ‎lioness
‎prince + ‎-ess → ‎princess (“daughter of monarch (holding this title in her own right, who would become a queen regnant); the female equivalent of a prince”)

2. The wife of.
‎alderman + ‎-ess → ‎aldermaness (“alderman’s wife”)
‎duke + ‎-ess → ‎duchess (“duke’s wife”)
‎mayor + ‎-ess → ‎mayoress (“mayor’s wife”)
‎priest + ‎-ess → ‎priestess (“priest’s wife”)
‎prince + ‎-ess → ‎princess (“prince’s wife (who would become a queen consort)”)
‎squire + ‎-ess → ‎squiress (“squire’s wife”)


Generalization:
-tor/-ter & -tress (actor vs. actress)
/ & -ess (host vs. hostess)
-x & -xxess (god vs. goddess)
-e & -ss (prince vs. princess)
-ke & -chess (duke vs. duchess)

coner case:
master vs. mistress
"""

# %%
"""
-ine

1. (non-productive) Used to form feminine nouns.
‎hero + ‎-ine → ‎heroine
‎speaker + ‎-ine → ‎speakerine (not in wordnet)

2. (non-productive) Used to form female given names or names of titles.
‎Clement + ‎-ine → ‎Clementine
‎landgrave + ‎-ine → ‎landgravine


Generalization:
/ & -ine
-xe & -xine ?
"""

# %%
"""
-ette

1. Used to form nouns meaning or implying the female equivalent of.
‎major + ‎-ette → ‎majorette
‎bachelor + ‎-ette → ‎bachelorette
‎smurf + ‎-ette → ‎Smurfette


Generalization:
/ & -ette
"""

# %%
"""
-rix

1. (often dated) Appended to words, chiefly verbs, to form female agent nouns.
For masculine agent nouns ending in -or, the feminine equivalent ending in -rix is the etymologically consistent form; however, in some cases the common feminine form has changed to become the one ending in -ess instead. 
For example, the common feminine form of actor is actress, and no longer the earlier form actrix.
"""

# %%
"""
-a

1. Marks nouns, with a foundation in Italian, Spanish, or Portuguese, implying femininity.
donna
signora


Generalization:
/ & -a
-x & -xxa ?
"""

# %%
import pandas as pd
from tqdm import tqdm


# Load CSV file into DataFrame
df = pd.read_csv("gender_synset_based_new_4.csv")

# %%
"""
-tor/-ter & -tress (actor vs. actress)
"""

lemma_dict = {}


def contains_woman(word):
    return "tress" in word.lower()

def replace_woman_with_man(word):
    return word.replace("tress", "tor")

def replace_woman_with_man_2(word):
    return word.replace("tress", "ter")

count = 0
for index, row in df.iterrows():
    lemma = str(row["Lemma"])
    gender = row["Gender"]
    definition = row["Definition"]
    if contains_woman(lemma):
        man_version = replace_woman_with_man(lemma)
        man_row = df[df["Lemma"] == man_version]
        if not man_row.empty:
            man_gender = man_row.iloc[0]["Gender"]
            man_def = man_row.iloc[0]["Definition"]
            print("{}, {}, {}".format(man_version, man_gender, man_def))
        else:
            man_version = replace_woman_with_man_2(lemma)
            man_row = df[df["Lemma"] == man_version]
            if not man_row.empty:
                man_gender = man_row.iloc[0]["Gender"]
                man_def = man_row.iloc[0]["Definition"]
                print("{}, {}, {}".format(man_version, man_gender, man_def))
            else:
                print('NA')
        count += 1

        # neutral_version = replace_woman_with_person(lemma)
        # neu_row = df[df["Lemma"] == neutral_version]
        # if not neu_row.empty:
        #     neu_gender = neu_row.iloc[0]["Gender"]
        #     neu_def = neu_row.iloc[0]["Definition"]
        #     print("{}, {}, {}".format(neutral_version, neu_gender, neu_def))
        # else:
        #     print('NA')
        print("{}, {}, {}".format(lemma, gender, definition))

print(count)
# Out:
# actor, N, a theatrical performer
# actress, F, a female actor
# ancestor, N, someone from whom you are descended (but usually more remote than a grandparent)
# ancestress, F, a woman ancestor
# aviator, N, someone who operates an aircraft
# aviatress, F, a woman aviator
# NA
# ballet_mistress, F, a woman who directs and teaches and rehearses dancers for a ballet company
# benefactor, N, a person who helps people or institutions (especially with financial help)
# benefactress, F, a woman benefactor
# conductor, N, the person who leads a musical group
# conductress, F, a woman conductor
# enchanter, N, a sorcerer or magician
# enchantress, F, a woman who is considered to be dangerously seductive
# enchanter, N, a sorcerer or magician
# enchantress, F, a female sorcerer or magician
# fornicator, N, someone who commits adultery or fornication
# fornicatress, F, a woman adulterer
# NA
# games-mistress, N, the teacher in charge of games at a school
# NA
# headmistress, F, a woman headmaster
# hunter, N, someone who hunts game
# huntress, F, a woman hunter
# idolater, N, a person who worships idols
# idolatress, F, a woman idolater
# inheritor, nan, a person who is entitled by law or by the terms of a will to inherit the estate of another
# inheritress, F, a female heir
# instructor, N, a person whose occupation is teaching
# instructress, F, a woman instructor
# NA
# mistress, F, an adulterous woman; a woman who has an ongoing extramarital sexual relationship with a man
# NA
# mistress, F, a woman schoolteacher (especially one regarded as strict)
# NA
# mistress, F, a woman master who directs the work of others
# negotiator, N, someone who negotiates (confers with others in order to reach a settlement)
# negotiatress, F, a woman negotiator
# NA
# postmistress, F, a woman postmaster
# proprietor, nan, (law) someone who owns (is legal possessor of) a business
# proprietress, F, a woman proprietor
# NA
# schoolmistress, F, a woman schoolteacher (especially one regarded as strict)
# sculptor, N, an artist who creates sculptures
# sculptress, F, a woman sculptor
# seamster, N, a person whose occupation is making and altering garments
# seamstress, N, someone who makes or mends dresses
# NA
# seductress, F, a woman who seduces
# NA
# sempstress, N, someone who makes or mends dresses
# songster, N, a composer of words or music for popular songs
# songstress, F, a woman songster (especially of popular songs)
# NA
# taskmistress, F, a woman taskmaster
# tempter, N, a person who tempts others
# temptress, F, a woman who is considered to be dangerously seductive
# NA
# toast_mistress, F, a woman toastmaster
# traitor, N, someone who betrays his country by committing treason
# traitress, F, female traitor
# waiter, N, a person whose occupation is to serve at table (as in a restaurant)
# waitress, F, a woman waiter
# 32

# %%
"""
/ & -ess (host vs. hostess)
"""

def contains_woman(word):
    lowercase_word = word.lower()
    return lowercase_word.endswith("ess")

def replace_woman_with_man(word):
    return word.replace("ess", "")

count = 0
for index, row in df.iterrows():
    lemma = str(row["Lemma"])
    gender = row["Gender"]
    definition = row["Definition"]
    if contains_woman(lemma):
        man_version = replace_woman_with_man(lemma)
        man_row = df[df["Lemma"] == man_version]
        if not man_row.empty:
            man_gender = man_row.iloc[0]["Gender"]
            man_def = man_row.iloc[0]["Definition"]
            print("{}, {}, {}".format(man_version, man_gender, man_def))

            count += 1

            print("{}, {}, {}".format(lemma, gender, definition))

print(count)
# Out:
# author, nan, writes (books or stories or articles or the like) professionally (for pay)
# authoress, F, a woman author
# baron, nan, a nobleman (in various countries) of varying rank
# baroness, F, a noblewoman who holds the rank of baron or who is the wife or widow of a baron
# count, nan, a nobleman (in various countries) having rank equal to a British earl
# countess, F, female equivalent of a count or earl
# deacon, N, a Protestant layman who assists the minister
# deaconess, F, a woman deacon
# giant, N, a person of exceptional importance and reputation
# giantess, F, a female giant
# heir, nan, a person who is entitled by law or by the terms of a will to inherit the estate of another
# heiress, F, a female heir
# host, N, a person who invites guests to a social event (such as a party in his or her own home) and who is responsible for them while they are there
# hostess, F, a woman host
# host, N, a person who invites guests to a social event (such as a party in his or her own home) and who is responsible for them while they are there
# hostess, F, a woman innkeeper
# host, N, a person who invites guests to a social event (such as a party in his or her own home) and who is responsible for them while they are there
# hostess, F, a woman steward on an airplane
# jew, N, a person belonging to the worldwide group claiming descent from Jacob (or converted to it) and connected by cultural or religious ties
# jewess, F, a woman who is a Jew
# manager, N, someone who controls resources and expenditures
# manageress, F, a woman manager
# mayor, N, the head of a city government
# mayoress, F, the wife of a mayor
# mayor, N, the head of a city government
# mayoress, F, a woman mayor
# patron, N, a regular customer
# patroness, F, a woman who is a patron or the wife of a patron
# peer, N, a person who is of equal standing with another in a group
# peeress, F, a woman of the peerage in Britain
# poet, nan, a writer of poems (the term is usually reserved for writers of good poetry)
# poetess, F, a woman poet
# priest, N, a clergyman in Christian churches who has the authority to perform or administer various religious rites; one of the Holy Orders
# priestess, F, a woman priest
# prior, N, the head of a religious order; in an abbey the prior is next below the abbot
# prioress, N, the superior of a group of nuns
# prophet, N, an authoritative person who divines the future
# prophetess, F, a woman prophet
# python, nan, a soothsaying spirit or a person who is possessed by such a spirit
# pythoness, nan, a witch with powers of divination
# python, nan, a soothsaying spirit or a person who is possessed by such a spirit
# pythoness, PPN, (Greek mythology) the priestess of Apollo at Delphi who transmitted the oracles
# shepherd, N, a clergyman who watches over a group of people
# shepherdess, F, a woman shepherd
# steward, N, someone who manages property or other affairs for someone else
# stewardess, F, a woman steward on an airplane
# titan, N, a person of exceptional importance and reputation
# titaness, PPN, (Greek mythology) any of the primordial giant goddesses who were offspring of Uranus (heaven) and Gaea (earth) in ancient mythology
# villain, N, a wicked or evil person; someone who does evil deliberately
# villainess, F, a woman villain
# viscount, nan, (in various countries) a son or younger brother or a count
# viscountess, F, a wife or widow of a viscount
# viscount, nan, (in various countries) a son or younger brother or a count
# viscountess, F, a noblewoman holding the rank of viscount in her own right
# ass, N, a pompous fool
# assess, N, a pompous fool
# 28

# %%
"""
-e & -ss (prince vs. princess)
"""

def contains_woman(word):
    lowercase_word = word.lower()
    return lowercase_word.endswith("ess")

def replace_woman_with_man(word):
    return word.replace("ess", "e")

count = 0
for index, row in df.iterrows():
    lemma = str(row["Lemma"])
    gender = row["Gender"]
    definition = row["Definition"]
    if contains_woman(lemma):
        man_version = replace_woman_with_man(lemma)
        man_row = df[df["Lemma"] == man_version]
        if not man_row.empty:
            man_gender = man_row.iloc[0]["Gender"]
            man_def = man_row.iloc[0]["Definition"]
            print("{}, {}, {}".format(man_version, man_gender, man_def))

            count += 1

            print("{}, {}, {}".format(lemma, gender, definition))

print(count)
# Out:
# abbe, N, a French abbot
# abbess, N, the superior of a group of nuns
# crown_prince, M, a male heir apparent to a throne
# crown_princess, F, the wife of a crown prince
# crown_prince, M, a male heir apparent to a throne
# crown_princess, F, a female heir apparent to a throne
# millionaire, N, a person whose material wealth is valued at more than a million dollars
# millionairess, F, a woman millionaire
# ogre, N, a cruel wicked and inhuman person
# ogress, nan, (folklore) a female ogre
# prince, M, a male member of a royal family other than the sovereign (especially the son of a sovereign)
# princess, F, a female member of a royal family other than the queen (especially the daughter of a sovereign)
# 6

# %%
"""
-x & -xess (god vs. goddess)
"""

def contains_woman(word):
    lowercase_word = word.lower()
    return lowercase_word.endswith("ess")

def replace_woman_with_man(word):
    removed_ess = word.replace("ess", "")
    removed_last_char = removed_ess[:-1]
    return removed_last_char

count = 0
for index, row in df.iterrows():
    lemma = str(row["Lemma"])
    gender = row["Gender"]
    definition = row["Definition"]
    if contains_woman(lemma):
        man_version = replace_woman_with_man(lemma)
        man_row = df[df["Lemma"] == man_version]
        if not man_row.empty:
            man_gender = man_row.iloc[0]["Gender"]
            man_def = man_row.iloc[0]["Definition"]
            print("{}, {}, {}".format(man_version, man_gender, man_def))

            count += 1

            print("{}, {}, {}".format(lemma, gender, definition))

print(count)
# Out:
# earth-god, nan, a god of fertility and vegetation
# earth-goddess, F, a goddess of fertility and vegetation
# earth_god, nan, a god of fertility and vegetation
# earth_goddess, F, a goddess of fertility and vegetation
# god, nan, the supernatural being conceived as the perfect and omnipotent and omniscient originator and ruler of the universe; the object of worship in monotheistic religions
# goddess, F, a female deity
# hunt, PPN, Englishman and Pre-Raphaelite painter (1827-1910)
# huntress, F, a woman hunter
# poe, PPN, United States writer and poet (1809-1849)
# poetess, F, a woman poet
# ward, N, a person who is under the protection or in the custody of another
# wardress, F, a woman warder
# wit, N, a witty amusing person who makes jokes
# witness, N, someone who sees an event and reports what happened
# wit, N, a witty amusing person who makes jokes
# witness, N, a close observer; someone who looks at something (such as an exhibition of some kind)
# wit, N, a witty amusing person who makes jokes
# witness, nan, (law) a person who attests to the genuineness of a document or signature by adding their own signature
# wit, N, a witty amusing person who makes jokes
# witness, nan, (law) a person who testifies under oath in a court of law
# 10

# %%
"""
-ke & -chess (duke vs. duchess)
"""

def contains_woman(word):
    lowercase_word = word.lower()
    return lowercase_word.endswith("chess")

def replace_woman_with_man(word):
    return word.replace("chess", "ke")

count = 0
for index, row in df.iterrows():
    lemma = str(row["Lemma"])
    gender = row["Gender"]
    definition = row["Definition"]
    if contains_woman(lemma):
        man_version = replace_woman_with_man(lemma)
        man_row = df[df["Lemma"] == man_version]
        if not man_row.empty:
            man_gender = man_row.iloc[0]["Gender"]
            man_def = man_row.iloc[0]["Definition"]
            print("{}, {}, {}".format(man_version, man_gender, man_def))

            count += 1

            print("{}, {}, {}".format(lemma, gender, definition))

print(count)
# Out:
# archduke, M, a sovereign prince of the former ruling house of Austria
# archduchess, F, a wife or widow of an archduke or a princess of the former ruling house of Austria
# duke, M, a British peer of the highest rank
# duchess, F, the wife of a duke or a woman holding ducal title in her own right
# grand_duke, M, a prince who rules a territory
# grand_duchess, F, the wife of a grand duke or a woman holding that rank in her own right
# 3

# %%
"""
/ & -ine
"""

def contains_woman(word):
    lowercase_word = word.lower()
    return lowercase_word.endswith("ine")

def replace_woman_with_man(word):
    return word.replace("ine", "")

count = 0
for index, row in df.iterrows():
    lemma = str(row["Lemma"])
    gender = row["Gender"]
    definition = row["Definition"]
    if contains_woman(lemma):
        man_version = replace_woman_with_man(lemma)
        man_row = df[df["Lemma"] == man_version]
        if not man_row.empty:
            man_gender = man_row.iloc[0]["Gender"]
            man_def = man_row.iloc[0]["Definition"]
            print("{}, {}, {}".format(man_version, man_gender, man_def))

            count += 1

            print("{}, {}, {}".format(lemma, gender, definition))

print(count)
# Out:
# benedict, PPN, United States anthropologist (1887-1948)
# benedictine, M, a monk or nun belonging to the order founded by Saint Benedict
# cather, PPN, United States writer who wrote about frontier life (1873-1947)
# catherine, PPN, first wife of Henry VIII; Henry VIII's divorce from her was the initial step of the Reformation in England (1485-1536)
# cather, PPN, United States writer who wrote about frontier life (1873-1947)
# catherine, PPN, empress of Russia who greatly increased the territory of the empire (1729-1796)
# hero, M, a man distinguished by exceptional courage and nobility and strength
# heroine, F, the main good female character in a work of fiction
# hero, M, a man distinguished by exceptional courage and nobility and strength
# heroine, F, a woman possessing heroic qualities or a woman who has performed heroic deeds
# mach, PPN, Austrian physicist and philosopher who introduced the Mach number and who founded logical positivism (1838-1916)
# machine, N, an efficient person
# pa, nan, an informal term for a father; probably derived from baby talk
# paine, PPN, American Revolutionary leader and signer of the Declaration of Independence (1731-1814)
# pa, nan, an informal term for a father; probably derived from baby talk
# paine, PPN, American Revolutionary leader and pamphleteer (born in England) who supported the American colonist's fight for independence and supported the French Revolution (1737-1809)
# 8

# %%
"""
/ & -ette
"""

def contains_woman(word):
    lowercase_word = word.lower()
    return lowercase_word.endswith("ette")

def replace_woman_with_man(word):
    return word.replace("ette", "")

count = 0
for index, row in df.iterrows():
    lemma = str(row["Lemma"])
    gender = row["Gender"]
    definition = row["Definition"]
    if contains_woman(lemma):
        man_version = replace_woman_with_man(lemma)
        man_row = df[df["Lemma"] == man_version]
        if not man_row.empty:
            man_gender = man_row.iloc[0]["Gender"]
            man_def = man_row.iloc[0]["Definition"]
            print("{}, {}, {}".format(man_version, man_gender, man_def))

            count += 1

            print("{}, {}, {}".format(lemma, gender, definition))

print(count)
# Out:
# bachelor, M, a man who has never been married
# bachelorette, F, a young unmarried woman who lives alone
# drum_major, N, the leader of a marching band or drum corps
# drum_majorette, F, a female baton twirler who accompanies a marching band
# drum_major, N, the leader of a marching band or drum corps
# drum_majorette, F, a female drum major
# farmer, N, a person who operates a farm
# farmerette, F, a woman working on a farm
# major, N, a commissioned military officer in the United States Army or Air Force or Marines; below lieutenant colonel and above captain
# majorette, F, a female baton twirler who accompanies a marching band
# major, N, a commissioned military officer in the United States Army or Air Force or Marines; below lieutenant colonel and above captain
# majorette, F, a female drum major
# usher, PPN, Irish prelate who deduced from the Bible that Creation occurred in the year 4004 BC (1581-1656)
# usherette, F, a female usher
# 7

# %%
"""
/ & -a
"""

def contains_woman(word):
    lowercase_word = word.lower()
    return lowercase_word.endswith("a")

def replace_woman_with_man(word):
    return word[:-1]

count = 0
for index, row in df.iterrows():
    lemma = str(row["Lemma"])
    gender = row["Gender"]
    definition = row["Definition"]
    if contains_woman(lemma):
        man_version = replace_woman_with_man(lemma)
        man_row = df[df["Lemma"] == man_version]
        if not man_row.empty:
            man_gender = man_row.iloc[0]["Gender"]
            man_def = man_row.iloc[0]["Definition"]
            print("{}, {}, {}".format(man_version, man_gender, man_def))
            count += 1
            print("{}, {}, {}".format(lemma, gender, definition))
            
print(count)
# Out:
# amor, PPN, (Roman mythology) god of love; counterpart of Greek Eros
# amora, PPN, one of a group of rabbis (active AD 250-500) who discussed the Mishnaic law in the law schools of Palestine and Mesopotamia where they explained and applied earlier teachings and whose discussions are recorded in the Talmud; they emphasized the study of Torah and the importance of personal action and the fulfillment of the commandments
# dad, nan, an informal term for a father; probably derived from baby talk
# dada, nan, an informal term for a father; probably derived from baby talk
# fascist, N, an adherent of fascism or other right-wing authoritarian views
# fascista, N, an Italian fascist under Mussolini
# frey, PPN, (Norse mythology) god of earth's fertility and peace and prosperity; son of Njorth and brother of Freya; originally of the Vanir; later with the Aesir
# freya, PPN, (Norse mythology) goddess of love and fecundity; daughter of Njorth and sister of Frey
# frigg, PPN, (Norse mythology) goddess of the heavens and married love; wife of Odin
# frigga, PPN, (Norse mythology) goddess of the heavens and married love; wife of Odin
# ganesh, nan, Hindu god of wisdom or prophecy; the god who removes obstacles
# ganesha, nan, Hindu god of wisdom or prophecy; the god who removes obstacles
# goy, N, a Christian as contrasted with a Jew
# goya, PPN, Spanish painter well known for his portraits and for his satires (1746-1828)
# hel, PPN, (Norse mythology) goddess of the dead and queen of the underworld
# hela, PPN, (Norse mythology) goddess of the dead and queen of the underworld
# indian, N, a member of the race of people living in America when Europeans arrived
# indiana, PPN, United States pop artist (born 1928)
# jagannath, nan, an avatar of Vishnu
# jagannatha, nan, an avatar of Vishnu
# kami, nan, one the Shinto deities (including mythological beings, spirits of distinguished men, forces of nature)
# kamia, N, a member of a North American Indian people of southeastern California and northwestern Mexico
# mam, N, a member of a Mayan people of southwestern Guatemala
# mama, nan, informal terms for a mother
# mam, N, a member of a Mayan people of southwestern Guatemala
# mama, N, a name under which Ninkhursag was worshipped
# markov, PPN, Russian mathematician (1856-1922)
# markova, PPN, English ballet dancer (born in 1910)
# pavlov, PPN, Russian physiologist who observed conditioned salivary responses in dogs (1849-1936)
# pavlova, PPN, Russian ballerina (1882-1931)
# phantasm, N, a ghostly appearing figure
# phantasma, N, a ghostly appearing figure
# ram, nan, (astrology) a person who is born while the sun is in Aries
# rama, nan, avatar of Vishnu whose name is synonymous with God; any of three incarnations: Ramachandra or Parashurama or Balarama
# sheik, N, the leader of an Arab village or family
# sheika, F, the wife of a sheik
# sheikh, N, the leader of an Arab village or family
# sheikha, F, the wife of a sheik
# signor, nan, used as an Italian courtesy title; can be prefixed to the name or used separately
# signora, nan, an Italian title of address equivalent to Mrs. when used before a name
# tzar, PPN, a male monarch or emperor (especially of Russia prior to 1917)
# tzara, PPN, French poet (born in Romania) who was one of the cofounders of the dada movement (1896-1963)
# 21
